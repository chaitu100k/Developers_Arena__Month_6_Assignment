# %% [markdown]
# # Evaluation & Dashboard
#
# Evaluation metrics and a small Streamlit dashboard example (instructions).

# %%
# Evaluation snippet
DATA_PATH = "C:/Users/Asus/Documents/Developers_Arena_Internship_Files/Month_6_Internship_files/traffic_flow_project/traffic_flow_project/data/synthetic_traffic_dataset.csv"
import pandas as pd
from sklearn.metrics import mean_squared_error
import joblib


df = pd.read_csv(DATA_PATH, parse_dates=['timestamp'])
# This cell is illustrative; adapt column names as needed.
print('Edit this notebook to match your feature engineering pipeline')
# Out:
# Edit this notebook to match your feature engineering pipeline
